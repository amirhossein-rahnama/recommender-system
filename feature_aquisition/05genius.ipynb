# %%
from bs4 import BeautifulSoup
import re
import requests
from thefuzz import fuzz
import pandas as pd
import time

# %% [markdown]
# # urls from genius api

# %%
def are_strings_similar(str1, str2, threshold=70):
    similarity_score = fuzz.ratio(str1, str2)
    return similarity_score >= threshold

# %%
# Replace 'YOUR_API_KEY' with your actual Genius API key
api_key = 'EOF7HOB8HPEY4xJvOSAxjNvmlsjp9jrVU20FphTY101MCi6PmBePEU8s-3KirNd5'

# Define the base URL for the Genius API
base_url = 'https://api.genius.com/'

# Define the endpoint for searching a song by its title and artist
search_endpoint = 'search'

#function with song title and artist name as parameters and returns the lyrics url
def get_lyrics_url(song_title, artist_name):
    #only take the first artist
    artist_names = artist_name.split(",")

    # Create a headers dictionary with the 'Authorization' field containing your API key
    headers = {
        'Authorization': f'Bearer {api_key}'
    }

    # Create a dictionary with query parameters for the search request
    params = {
        'q': f'{song_title} {artist_names[0]}'
    }

    # Make the GET request to search for the song
    response = requests.get(f'{base_url}{search_endpoint}', headers=headers, params=params)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        data = response.json()
        # Extract relevant information from the response
        song_hits = data['response']['hits']
        #iterate through the song hits and find the song with the correct artist
        for hit in song_hits:
            #check if hit type is song
            if hit['type'] == 'song':
                song_info = hit['result']
                artist = song_info['primary_artist']['name']
                if are_strings_similar(song_info['title'].lower(), song_title):
                    #check if one of artist_names is similar to artist
                    for artist_name in artist_names:
                        if are_strings_similar(artist.lower(), artist_name):
                            #check lyrics is available
                            if song_info['lyrics_state'] == 'complete':
                                #get lyrics url
                                return song_info['url']
                            else:
                                #return lyrics state
                                return f'lyrics state: {song_info["lyrics_state"]}'
        #if no song is found, return None
        return None
    else:
        time.sleep(60)
        return(f'Error: {response.status_code}')

# %%
#TEST
get_lyrics_url('africa', 'toto')
# Out:
# 'https://genius.com/Toto-africa-lyrics'

# %%
#load first genius dataframe 
df = pd.read_csv('no_lyrics.csv')
df.shape
# Out:
# (8865, 37)

# %%
#get the urls for every song
for index, row in df.iterrows():
    try:
        df.at[index, 'lyrics_url'] = get_lyrics_url(row['clear_name'], row['artists'])
    except:
        df.at[index, 'lyrics_url'] = 'Error'

# %%
#how many songs have a lyrics url
df_with_url = df[df['lyrics_url'].str.contains('genius.com', na=False)]
df_with_url.shape
# Out:
# (910, 37)

# %%
#make dataframe with songs without lyrics url
df_without = df[~df['uri'].isin(df_with_url['uri'])]
df_without.shape
# Out:
# (7955, 37)

# %% [markdown]
# now restart getting the urls. this time outcomment the artist in the search query (marked with comment in get_lyrics_url)

# %%
def url_info(genius_df):    
    #count the number of None in gerius_df
    null_cnt = genius_df[genius_df['lyrics_url'].isnull()].shape[0]
    #count the number of "Error: 503" in gerius_df
    error_cnt = genius_df[genius_df['lyrics_url'] == 'Error: 503'].shape[0]
    #count the number of "Error" in gerius_df
    error_cnt2 = genius_df[genius_df['lyrics_url'] == 'Error'].shape[0]
    #count the number of "lyrics state: unreleased" in gerius_df
    unreleased_cnt = genius_df[genius_df['lyrics_url'] == 'lyrics state: unreleased'].shape[0]
    #count the number of nan in gerius_df
    nan_cnt = genius_df[genius_df['lyrics_url'] == 'nan'].shape[0]
    #print all counts
    print(f'null_cnt: {null_cnt}')
    print(f'error_cnt: {error_cnt}')
    print(f'error_cnt2: {error_cnt2}')
    print(f'unreleased_cnt: {unreleased_cnt}')
    print(f'nan_cnt: {nan_cnt}')

# %%
url_info(df_without)
# Out:
# null_cnt: 7893
# error_cnt: 0
# error_cnt2: 0
# unreleased_cnt: 62
# nan_cnt: 0

# %% [markdown]
# > ⚠️ Don't forget to store the resulting dataframes

# %% [markdown]
# # webscrape lyrics from genius urls

# %%
def extract_lyrics_from_genius_html(html):
    try:
        # Parse the HTML content
        soup = BeautifulSoup(html.replace('<br/>', '\n'), "html.parser")
        # Find the element that contains the lyrics
        divs = soup.find_all("div", class_=re.compile("^lyrics$|Lyrics__Container"))
        if divs is None or len(divs) == 0:
            return False, None
        lyrics = "\n".join([div.get_text() for div in divs])
        # Remove [Verse], [Bridge], etc.
        lyrics = re.sub(r'(\[.*?\])*', '', lyrics)
        lyrics = re.sub('\n{2}', '\n', lyrics)  # Gaps between verses
        return True, lyrics.strip("\n")
    except Exception as e:
        return False, "An error occurred: " + str(e)

# %%
def get_html_from_url(url):
    try:
        # Send an HTTP GET request to the URL
        response = requests.get(url)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Get the HTML content
            html = response.text
            return True, html
        else:
            print("HTTP GET request failed with status code: " + str(response.status_code))
            return False, f"HTTP GET request failed with status code: {response.status_code}"

    except Exception as e:
        return False, "An error occurred: " + str(e)

# %%
#TEST
url = "https://genius.com/Ac-dc-back-in-black-lyrics"
ok, html = get_html_from_url(url)
ok, lyrics = extract_lyrics_from_genius_html(html)
print(lyrics)
# Out:
# Back in black, I hit the sack
# I've been too long, I'm glad to be back
# Yes, I'm let loose from the noose
# That's kept me hanging about
# I'm just looking at the sky 'cause it's getting me high
# Forget the hearse, 'cause I'll never die
# I got nine lives, cat's eyes
# Abusing every one of them and running wild
#
# 'Cause I'm back
# Yes, I'm back
# Well, I'm back
# Yes, I'm back
# Well, I'm back, back
# Well, I'm back in black
# Yes, I'm back in black
#
# Back in the back of a Cadillac
# Number one with a bullet, I'm a power pack
# Yes, I'm in a bang with a gang
# They've got to catch me if they want me to hang
# 'Cause I'm back on the track and I'm beatin' the flack
# Nobody's gonna get me on another rap
# So, look at me now, I'm just making my play
# Don't try to push your luck, just get out of my way
#
# 'Cause I'm back
# Yes, I'm back
# Well, I'm back
# Yes, I'm back
# Well, I'm back, back
# Well, I'm back in black
# Yes, I'm back in black
#
#
# Well, I'm back
# Yes, I'm back
# Well, I'm back
# Yes, I'm back
# Well, I'm back, back
# Well, I'm back in black
# Yes, I'm back in black, yow
#
# Ah, yeah
# Oh, yeah
# Take my love
# Yeah, yeah
# Yeah
# Ah, hey yeah
# Ooh, yeah
#
# Well, I'm back (I'm back)
# Back (Well, I'm back)
# Back (I'm back)
# Back (I'm back)
# Back (I'm back)
# Back, back in black
# Yes, I'm back in black
#
# I've hit the sack

# %%
def get_lyrics_from_genius(df, output_path='lyrics.csv'):
    #create a new column for the lyrics
    df['lyrics'] = ''
    
    #reset index
    df.reset_index(drop=True, inplace=True)

    df_length = len(df)
    #5% of the length
    step = df_length // 100

    error_cnt = 0
    step_cnt = 0
    
    #iterate through the dataframe
    for index, row in df.iterrows():

        #print the progress
        if index % step == 0:
            print(f"progress: {index} / {df_length}")
            # if error_cnt > 0 and error_cnt == step_cnt:
            #     print("too many errors, stop")
            #     break
            # else:
            #     error_cnt = 0
            #     step_cnt = 0
        #get the url
        url = row['lyrics_url']
        #get the html
        ok, html = get_html_from_url(url)

        if ok:
            #extract the lyrics
            ok, lyrics = extract_lyrics_from_genius_html(html)
            if not ok:
                error_cnt += 1
                print(lyrics)
        else:
            error_cnt += 1
            print(html)
        
        #update the dataframe
        df.at[index, 'lyrics'] = lyrics
        
        step_cnt += 1
        
        #wait for 1 second
        #time.sleep(3)
    #save the dataframe
    df.to_csv(output_path, index=False)

# %%
# scrape the lyrics
get_lyrics_from_genius(df_with_url, 'lyrics.csv')
# Out:
# C:\Users\Maddin\AppData\Local\Temp\ipykernel_5180\3215287913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lyrics'] = ''
# progress: 0 / 910
# None
# None
# None
# progress: 9 / 910
# None
# None
# None
# progress: 18 / 910
# None
# None
# None
# progress: 27 / 910
# None
# None
# None
# None
# None
# progress: 36 / 910
# None
# None
# None
# None
# progress: 45 / 910
# None
# None
# None
# progress: 54 / 910
# None
# None
# None
# None
# None
# progress: 63 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 72 / 910
# None
# None
# None
# None
# None
# None
# progress: 81 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 90 / 910
# None
# None
# None
# None
# None
# progress: 99 / 910
# None
# None
# None
# None
# None
# None
# progress: 108 / 910
# None
# None
# None
# None
# None
# None
# progress: 117 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 126 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 135 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 144 / 910
# None
# None
# None
# None
# None
# progress: 153 / 910
# None
# None
# None
# None
# None
# progress: 162 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 171 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 180 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 189 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 198 / 910
# None
# None
# None
# None
# None
# None
# progress: 207 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 216 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 225 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 234 / 910
# None
# None
# None
# None
# None
# None
# progress: 243 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 252 / 910
# None
# None
# None
# None
# None
# None
# progress: 261 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 270 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 279 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 288 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 297 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 306 / 910
# None
# None
# None
# None
# None
# progress: 315 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 324 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 333 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 342 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 351 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 360 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 369 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 378 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 387 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 396 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 405 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 414 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 423 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 432 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 441 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 450 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 459 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 468 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 477 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 486 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 495 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 504 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 513 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 522 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 531 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 540 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 549 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 558 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 567 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 576 / 910
# None
# None
# None
# None
# None
# None
# progress: 585 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 594 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 603 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 612 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 621 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 630 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 639 / 910
# None
# None
# None
# None
# None
# None
# progress: 648 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 657 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 666 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 675 / 910
# None
# None
# None
# None
# None
# progress: 684 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 693 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 702 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 711 / 910
# None
# None
# None
# None
# progress: 720 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 729 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 738 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 747 / 910
# None
# None
# None
# None
# None
# progress: 756 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 765 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 774 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 783 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 792 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 801 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 810 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 819 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 828 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 837 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 846 / 910
# None
# None
# None
# None
# None
# None
# None
# progress: 855 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 864 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 873 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 882 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 891 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 900 / 910
# None
# None
# None
# None
# None
# None
# None
# None
# None
# progress: 909 / 910

# %%
df = pd.read_csv('lyrics.csv')

# %%
#count the number of songs with lyrics
df[~df['lyrics'].notnull()].shape
# Out:
# (735, 37)

# %%
df.sort_values(by=['popularity'], inplace=True)

# %%
df.head(10)
# Out:
#              isrc                                             genres
# 909  DEE860701147                                  ['german', 'pop']  \
# 889  GBEEL0600125                             ['industrial', 'rock']
# 888  GBEEL0600124                             ['industrial', 'rock']
# 887  QM4TW1576255            ['electro', 'electronic', 'industrial']
# 886  USRC10602214                                  ['dance', 'rock']
# 908  GBAYE1801177  ['blues', 'british', 'metal', 'psych-rock', 'r...
# 885  GB4971500225                             ['industrial', 'rock']
# 890  USMC17024885                                   ['rock', 'soul']
# 884  QMPKX1672969  ['ambient', 'industrial', 'punk', 'punk-rock',...
# 881  GBAJH0400621     ['alt-rock', 'alternative', 'british', 'rock']
#
#                          name                           artists
# 909      it's all in the game                              nena  \
# 889     rattlesnake insurance  foetus,the foetus all nude revue
# 888              sick minutes         foetus,foetus uber frisco
# 887            icepick method                     hunting lodge
# 886            shut your face                          polyrock
# 908                watch out!                    atomic rooster
# 885                      shut  foetus,the foetus all nude revue
# 890         cantaloupe island                        el chicano
# 884  come visit the big bigot                     severed heads
# 881          auto destruction                     barry adamson
#
#                                   album release_date release_date_precision
# 909                It's All in the Game   1985-08-10                    day  \
# 889                                Sink         1989                   year
# 888                                Sink         1989                   year
# 887                                Will         1983                   year
# 886                            Polyrock         1980                   year
# 908                      Atomic Rooster   1980-01-01                    day
# 885                                Sink         1989                   year
# 890  Viva El Chicano! (Their Very Best)   1988-01-01                    day
# 884          (Come Visit) the Big Bigot   1986-09-01                    day
# 881                     Moss Side Story   1989-03-06                    day
#
#                                       uri              spotify_id
# 909  spotify:track:2DjOVzUbgLQ0NUi4VF1lT8  2DjOVzUbgLQ0NUi4VF1lT8  \
# 889  spotify:track:3svNLYIQgvEfMw572uTPtv  3svNLYIQgvEfMw572uTPtv
# 888  spotify:track:17GmAhgpBjDHrhSQVf61px  17GmAhgpBjDHrhSQVf61px
# 887  spotify:track:3h4BTnJ7k2vKyL8FLqyYUr  3h4BTnJ7k2vKyL8FLqyYUr
# 886  spotify:track:2fNLJ7S3tchQcagTdRN4vg  2fNLJ7S3tchQcagTdRN4vg
# 908  spotify:track:4qSkje27kD8Vu7uYAhg9Rb  4qSkje27kD8Vu7uYAhg9Rb
# 885  spotify:track:0usGeQ8EHUH0kJcXLaH66Q  0usGeQ8EHUH0kJcXLaH66Q
# 890  spotify:track:2DEyIFKO7SW351whjJz8Pv  2DEyIFKO7SW351whjJz8Pv
# 884  spotify:track:3XsiMrV8V8y1J2BE54yh9m  3XsiMrV8V8y1J2BE54yh9m
# 881  spotify:track:4A2UUj7JtnzYnJemvigjpB  4A2UUj7JtnzYnJemvigjpB
#
#      chart_power  ...  Listeners  Playcount
# 909          NaN  ...        309       1707  \
# 889          NaN  ...       1854       5573
# 888          NaN  ...       2043       6511
# 887          NaN  ...       2213       4873
# 886          NaN  ...       2197       5869
# 908          NaN  ...        610       1379
# 885          NaN  ...       2090       7151
# 890          NaN  ...       1795       4816
# 884          NaN  ...       2272       6868
# 881          NaN  ...       3605       8264
#
#                                                   Tags
# 909  ['80s', 'new wave', 'Neue Deutsche Welle', '19...  \
# 889                                                 []
# 888  ['seen live', '80s', 'experimental', 'industri...
# 887                                                 []
# 886  ['new wave', 'post-punk', 'philip glass-punkro...
# 908                                                 []
# 885                                                 []
# 890                         ['zapfunk', 'rare groove']
# 884  ['post-punk', 'synth', 'Hell Yeah', 'songs by ...
# 881  ['dark', 'pop', '80s', 'experimental', 'cinema...
#
#                    clear_name
# 909      it's all in the game  \
# 889     rattlesnake insurance
# 888              sick minutes
# 887            icepick method
# 886            shut your face
# 908                watch out!
# 885                      shut
# 890         cantaloupe island
# 884  come visit the big bigot
# 881          auto destruction
#
#                                             lyrics_url
# 909  https://genius.com/Nena-its-all-in-the-game-ly...  \
# 889  https://genius.com/Foetus-rattlesnake-insuranc...
# 888      https://genius.com/Foetus-sick-minutes-lyrics
# 887  https://genius.com/Hunting-lodge-icepick-metho...
# 886  https://genius.com/Polyrock-shut-your-face-lyrics
# 908  https://genius.com/Atomic-rooster-watch-out-ly...
# 885              https://genius.com/Foetus-shut-lyrics
# 890  https://genius.com/El-chicano-cantaloupe-islan...
# 884  https://genius.com/Severed-heads-come-visit-th...
# 881  https://genius.com/Barry-adamson-autodestructi...
#
#                                                 lyrics  chart_peak
# 909  There was an old man\nWho was robbing himself ...           0  \
# 889                                                NaN           0
# 888                                                NaN           0
# 887                                                NaN           0
# 886                                                NaN           0
# 908                                                NaN           0
# 885                                                NaN           0
# 890                                                NaN           0
# 884                                                NaN           0
# 881                                                NaN           0
#
#      chart_weeks      rank  chart_rank
# 909            0  0.000118           0
# 889            0  0.000944           0
# 888            0  0.001063           0
# 887            0  0.001073           0
# 886            0  0.001105           0
# 908            0  0.000237           0
# 885            0  0.001108           0
# 890            0  0.000888           0
# 884            0  0.001177           0
# 881            0  0.001813           0
#
# [10 rows x 37 columns]

# %%
df2 = pd.read_csv('final_dataset.csv')
df2.shape
# Out:
# (45210, 36)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45210 entries, 0 to 45209
# Data columns (total 36 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   isrc                    45210 non-null  object
#  1   genres                  45210 non-null  object
#  2   name                    45210 non-null  object
#  3   artists                 45210 non-null  object
#  4   album                   45210 non-null  object
#  5   release_date            45210 non-null  object
#  6   release_date_precision  45210 non-null  object
#  7   uri                     45210 non-null  object
#  8   spotify_id              45210 non-null  object
#  9   popularity              45210 non-null  int64
#  10  danceability            45210 non-null  float64
#  11  energy                  45210 non-null  float64
#  12  key                     45210 non-null  int64
#  13  loudness                45210 non-null  float64
#  14  mode                    45210 non-null  int64
#  15  speechiness             45210 non-null  float64
#  16  acousticness            45210 non-null  float64
#  17  instrumentalness        45210 non-null  float64
#  18  liveness                45210 non-null  float64
#  19  valence                 45210 non-null  float64
#  20  tempo                   45210 non-null  float64
#  21  duration_ms             45210 non-null  int64
#  22  time_signature          45210 non-null  int64
#  23  year                    45210 non-null  int64
#  24  country_code            45210 non-null  object
#  25  country                 45210 non-null  object
#  26  Listeners               45210 non-null  int64
#  27  Playcount               45210 non-null  int64
#  28  Tags                    45210 non-null  object
#  29  clear_name              45209 non-null  object
#  30  lyrics_url              45210 non-null  object
#  31  lyrics                  45210 non-null  object
#  32  chart_peak              45210 non-null  int64
#  33  chart_weeks             45210 non-null  int64
#  34  rank                    45210 non-null  float64
#  35  chart_rank              45210 non-null  int64
# dtypes: float64(10), int64(11), object(15)
# memory usage: 12.4+ MB

# %%
#drop chart_power column
df.drop(columns=['chart_power'], inplace=True)
# Out:
# C:\Users\Maddin\AppData\Local\Temp\ipykernel_5180\474996279.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['chart_power'], inplace=True)

# %%
#concatenate the two dataframes
df3 = pd.concat([df2, df], axis=0)
df3.shape
# Out:
# (45385, 36)

# %%
#delete duplicates
df3.drop_duplicates(subset=['uri'], inplace=True)

# %%
df3.shape
# Out:
# (45385, 36)

# %%
df3.to_csv('final_dataset.csv', index=False)
